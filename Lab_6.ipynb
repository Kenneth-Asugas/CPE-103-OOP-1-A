# %% [markdown]
# <a href="https://colab.research.google.com/github/Kenneth-Asugas/CPE-103-OOP-1-A/blob/main/Lab_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Character():
  def __init__(self, username):
    self.__username = username
    self.__hp = 100
    self.__mana = 100
    self.__damage = 5
    self.__str = 0
    self.__vit = 0
    self.__int = 0
    self.__agi = 0
  def getUsername(self):
    return self.__username
  def setUsername(self, new_username):
    self.__username = new_username
  def getHp(self):
    return self.__hp
  def setHp(self, new_hp):
    self.__hp = new_hp
  def getDamage(self):
    return self.__damage
  def setDamage(self, new_damage):
    self.__damage = new_damage
  def getStr(self):
    return self.__str
  def setStr(self, new_str):
    self.__str = new_str
  def getVit(self):
    return self.__vit
  def setVit(self, new_vit):
    self.__vit = new_vit
  def getInt(self):
    return self.__int
  def setInt(self, new_int):
    self.__int = new_int
  def getAgi(self):
    return self.__agi
  def setAgi(self, new_agi):
    self.__agi = new_agi
  def reduceHp (self, damage_amount):
    self.__hp = self.__hp - damage_amount
  def addHp(self, heal_amount):
    self.__hp = self.__hp + heal_amount

character1 = Character("Ken")

print(character1.getUsername())
# Out:
# Ken

# %%
class Novice(Character):
    def basicAttack(self, character):
        character.reduceHp(self.getDamage())
        print(f"{self.getUsername()} performed Basic Attack! Damage: {self.getDamage()}")


character1 = Novice("Novice")


print(character1.getUsername())
print(character1.getHp())
# Out:
# Novice
# 100

# %%
class Swordsman (Novice):
  def __init__(self, username):
    super().__init__(username)
    self.setStr(5)
    self.setVit(10)
    self.setHp(self.getHp()+self.getVit())


  def slashAttack(self, character):
    self.new_damage = self.getDamage()+self.getStr()
    character.reduceHp(self.new_damage)
    print(f"{self.getUsername()} performed Slash Attack! -{self.new_damage}")

# %%
import random
class Archer (Novice):
  def __init__(self, username):
    super().__init__(username)
    self.setAgi(5)
    self.setInt(5)
    self.setVit(5)
    self.setHp(self.getHp()+self.getVit())
  def rangedAttack(self, character):
    self.new_damage = self.getDamage()+random.randint(0,self.getInt())
    character.reduceHp(self.new_damage)
    print(f"{self.getUsername()} performed Slash Attack! -{self.new_damage}")

# %%
class Magician (Novice):
  def __init__(self, username):
    super().__init__(username)
    self.setInt(10)
    self.setVit(5)
    self.setHp(self.getHp()+self.getVit())
  def heal(self):
    self.addHp(self.getInt())
    print(f"{self.getUsername()} performed Heal! +{self.getInt()}")
  def magicAttack(self, character):
    self.new_damage = self.getDamage()+self.getInt()
    character.reduceHp(self.new_damage)
    print(f"{self.getUsername()} performed Magic Attack! -{self.new_damage}")

# %%
Character1 = Swordsman ("Royce")
Character2 = Magician ("Archie")
print(f"{Character1.getUsername()} HP: {Character1.getHp()}")
print(f"{Character2.getUsername()} HP: {Character2.getHp()}")
Character1.slashAttack (Character2)
Character1.basicAttack (Character2)
print(f"{Character1.getUsername()} HP: {Character1.getHp()}")
print(f"{Character2.getUsername()} HP: {Character2.getHp()}")
Character2.heal()
Character2.magicAttack (Character1)
print(f"{Character1.getUsername()} HP: {Character1.getHp()}")
print(f"{Character2.getUsername()} HP: {Character2.getHp()}")
# Out:
# Royce HP: 110
# Archie HP: 105
# Royce performed Slash Attack! -10
# Royce performed Basic Attack! Damage: 5
# Royce HP: 110
# Archie HP: 90
# Archie performed Heal! +10
# Archie performed Magic Attack! -15
# Royce HP: 95
# Archie HP: 100

# %%
Character1 = Swordsman ("Royce")
Character2 = Magician ("Archie")
print(f"{Character1.getUsername()} HP: {Character1.getHp()}")
print(f"{Character2.getUsername()} HP: {Character2.getHp()}")
Character1.slashAttack (Character2)
Character1.basicAttack (Character2)
print(f"{Character1.getUsername()} HP: {Character1.getHp()}")
print(f"{Character2.getUsername()} HP: {Character2.getHp()}")
Character2.heal()
Character2.slashAttack (Character1)
print(f"{Character1.getUsername()} HP: {Character1.getHp()}")
print(f"{Character2.getUsername()} HP: {Character2.getHp()}")
# Out:
# Royce HP: 110
# Archie HP: 105
# Royce performed Slash Attack! -10
# Royce performed Basic Attack! Damage: 5
# Royce HP: 110
# Archie HP: 90
# Archie performed Heal! +10
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-46013dffd582> in <cell line: 0>()
#       8 print(f"{Character2.getUsername()} HP: {Character2.getHp()}")
#       9 Character2.heal()
# ---> 10 Character2.slashAttack (Character1)
#      11 print(f"{Character1.getUsername()} HP: {Character1.getHp()}")
#      12 print(f"{Character2.getUsername()} HP: {Character2.getHp()}")
#
# AttributeError: 'Magician' object has no attribute 'slashAttack'

# %%
class Boss(Swordsman, Archer, Magician):
  def __init__(self, username):
    super().__init__(username)
    self.setStr(10)
    self.setVit(25)
    self.setInt(5)
    self.setHp(self.getHp()+self.getVit())

# %%
Character1 = Swordsman ("Royce")
Character2 = Boss("Archie")
print(f"{Character1.getUsername()} HP: {Character1.getHp()}")
print(f"{Character2.getUsername()} HP: {Character2.getHp()}")
Character1.slashAttack (Character2)
Character1.basicAttack (Character2)
print(f"{Character1.getUsername()} HP: {Character1.getHp()}")
print(f"{Character2.getUsername()} HP: {Character2.getHp()}")
Character2.heal()
Character2.basicAttack (Character1)
Character2.slashAttack (Character1)
Character2.rangedAttack(Character1)
Character2.magicAttack(Character1)
print(f"{Character1.getUsername()} HP: {Character1.getHp()}")
print(f"{Character2.getUsername()} HP: {Character2.getHp()}")
# Out:
# Royce HP: 110
# Archie HP: 145
# Royce performed Slash Attack! -10
# Royce performed Basic Attack! Damage: 5
# Royce HP: 110
# Archie HP: 130
# Archie performed Heal! +5
# Archie performed Basic Attack! Damage: 5
# Archie performed Slash Attack! -15
# Archie performed Slash Attack! -10
# Archie performed Magic Attack! -10
# Royce HP: 70
# Archie HP: 135

# %% [markdown]
# Supplementary Activity

# %%
import random

class Character:
    def __init__(self, name, hp, damage):
        self.name = name
        self.hp = hp
        self.damage = damage

    def attack(self, target):
        target.hp -= self.damage
        print(f"{self.name} attacks {target.name} for {self.damage} damage!")

    def is_alive(self):
        return self.hp > 0

class Player(Character):
    ROLE_STATS = {
        "Novice": (100, 15),
        "Swordsman": (120, 20),
        "Archer": (100, 23),
        "Magician": (80, 25)
    }

    def __init__(self, name, role="Novice"):
        super().__init__(name, *self.ROLE_STATS[role])
        self.role = role

    def special_attack(self, target):
        special_damage = {"Swordsman": 30, "Archer": 35, "Magician": 50}.get(self.role, 0)
        target.hp -= special_damage
        print(f"{self.name} uses special attack for {special_damage} damage!")

    def heal(self):
        if self.role == "Magician":
            self.hp += 20
            print(f"{self.name} heals for 20 HP!")

class Monster(Character):
    def __init__(self):
        super().__init__("Monster", 100, 5)

class Game:
    def __init__(self):
        self.player_wins = {}
        self.start_game()

    def choose_role(self, is_first=True):
        roles = ["Swordsman", "Archer", "Magician"]
        if is_first:
            return Player(input("Enter your name: "))
        while True:
            print("Choose your new role: 1. Swordsman 2. Archer 3. Magician")
            choice = input("Enter choice: ")
            if choice in ["1", "2", "3"]:
                return Player(input("Enter your name: "), roles[int(choice) - 1])
            print("Invalid choice. Try again.")

    def battle(self, player, enemy):
        while player.is_alive() and enemy.is_alive():
            attacker, defender = random.sample([player, enemy], 2)
            print(f"{attacker.name}'s turn!")
            if isinstance(attacker, Monster):
                attacker.attack(defender)
            else:
                while True:
                    print("Choose attack: 1. Basic Attack 2. Special Attack" + (" 3. Heal" if player.role == "Magician" else ""))
                    move = input("Enter choice: ")
                    if move == "1":
                        attacker.attack(defender)
                        break
                    elif move == "2":
                        attacker.special_attack(defender)
                        break
                    elif move == "3" and attacker.role == "Magician":
                        attacker.heal()
                        break
                    print("Invalid choice. Try again.")
            print(f"{defender.name} HP: {defender.hp}")

        winner = player if player.is_alive() else enemy
        print(f"{winner.name} wins!")
        self.player_wins[winner.name] = self.player_wins.get(winner.name, 0) + 1
        print(f"{winner.name} has won {self.player_wins[winner.name]} times!")
        return player if player.is_alive() else None

    def single_player(self):
        player = self.choose_role()
        while True:
            print("A Monster appears!")
            if self.battle(player, Monster()):
                if self.player_wins[player.name] == 2:
                    print("You can choose a new role!")
                    player = self.choose_role(False)
                    self.player_wins[player.name] = 0
            else:
                print("You lost. Game over.")
                break

    def pvp(self):
        print("Player 1:")
        player1 = self.choose_role(False)
        print("Player 2:")
        player2 = self.choose_role(False)
        self.battle(player1, player2)

    def start_game(self):
        while True:
            print("Choose Mode: 1. Single Player 2. PvP 3. Exit")
            mode = input("Enter choice: ")
            if mode == "1":
                self.single_player()
            elif mode == "2":
                self.pvp()
            elif mode == "3":
                print("Exiting game...")
                break
            else:
                print("Invalid choice. Try again.")

if __name__ == "__main__":
    Game()
# Out:
# Choose Mode: 1. Single Player 2. PvP 3. Exit
# Enter choice: 1
# Enter your name: Ken
# A Monster appears!
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 15 damage!
# Monster HP: 85
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 95
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 2
# Ken uses special attack for 0 damage!
# Monster HP: 85
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 15 damage!
# Monster HP: 70
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 15 damage!
# Monster HP: 55
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 90
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 2
# Ken uses special attack for 0 damage!
# Monster HP: 55
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 85
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 80
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 75
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 70
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 15 damage!
# Monster HP: 40
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 65
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 60
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 55
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 15 damage!
# Monster HP: 25
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 15 damage!
# Monster HP: 10
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 50
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 15 damage!
# Monster HP: -5
# Ken wins!
# Ken has won 1 times!
# A Monster appears!
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 15 damage!
# Monster HP: 85
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 15 damage!
# Monster HP: 70
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 15 damage!
# Monster HP: 55
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 15 damage!
# Monster HP: 40
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 15 damage!
# Monster HP: 25
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 15 damage!
# Monster HP: 10
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 15 damage!
# Monster HP: -5
# Ken wins!
# Ken has won 2 times!
# You can choose a new role!
# Choose your new role: 1. Swordsman 2. Archer 3. Magician
# Enter choice: 2
# Enter your name: Ken
# A Monster appears!
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 95
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 90
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 85
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 80
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 23 damage!
# Monster HP: 77
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 23 damage!
# Monster HP: 54
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 75
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 23 damage!
# Monster HP: 31
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 70
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 23 damage!
# Monster HP: 8
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 23 damage!
# Monster HP: -15
# Ken wins!
# Ken has won 1 times!
# A Monster appears!
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 65
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 60
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 23 damage!
# Monster HP: 77
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 55
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 50
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 23 damage!
# Monster HP: 54
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 45
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 40
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 23 damage!
# Monster HP: 31
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 23 damage!
# Monster HP: 8
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 35
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 30
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 25
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 2
# Ken uses special attack for 35 damage!
# Monster HP: -27
# Ken wins!
# Ken has won 2 times!
# You can choose a new role!
# Choose your new role: 1. Swordsman 2. Archer 3. Magician
# Enter choice: 3
# Enter your name: Ken
# A Monster appears!
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 75
# Monster's turn!
# Monster attacks Ken for 5 damage!
# Ken HP: 70
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack 3. Heal
# Enter choice: 2
# Ken uses special attack for 50 damage!
# Monster HP: 50
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack 3. Heal
# Enter choice: 2
# Ken uses special attack for 50 damage!
# Monster HP: 0
# Ken wins!
# Ken has won 1 times!
# A Monster appears!
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack 3. Heal
# Enter choice: 2
# Ken uses special attack for 50 damage!
# Monster HP: 50
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack 3. Heal
# Enter choice: 2
# Ken uses special attack for 50 damage!
# Monster HP: 0
# Ken wins!
# Ken has won 2 times!
# You can choose a new role!
# Choose your new role: 1. Swordsman 2. Archer 3. Magician
# Enter choice: 0
# Invalid choice. Try again.
# Choose your new role: 1. Swordsman 2. Archer 3. Magician
# Enter choice:
# Invalid choice. Try again.
# Choose your new role: 1. Swordsman 2. Archer 3. Magician
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-0719776807fb> in <cell line: 0>()
#     119
#     120 if __name__ == "__main__":
# --> 121     Game()
#
# <ipython-input-17-0719776807fb> in __init__(self)
#      43     def __init__(self):
#      44         self.player_wins = {}
# ---> 45         self.start_game()
#      46
#      47     def choose_role(self, is_first=True):
#
# <ipython-input-17-0719776807fb> in start_game(self)
#     109             mode = input("Enter choice: ")
#     110             if mode == "1":
# --> 111                 self.single_player()
#     112             elif mode == "2":
#     113                 self.pvp()
#
# <ipython-input-17-0719776807fb> in single_player(self)
#      91                 if self.player_wins[player.name] == 2:
#      92                     print("You can choose a new role!")
# ---> 93                     player = self.choose_role(False)
#      94                     self.player_wins[player.name] = 0
#      95             else:
#
# <ipython-input-17-0719776807fb> in choose_role(self, is_first)
#      51         while True:
#      52             print("Choose your new role: 1. Swordsman 2. Archer 3. Magician")
# ---> 53             choice = input("Enter choice: ")
#      54             if choice in ["1", "2", "3"]:
#      55                 return Player(input("Enter your name: "), roles[int(choice) - 1])
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import random

class Character:
    def __init__(self, name, hp, damage):
        self.name = name
        self.hp = hp
        self.damage = damage

    def attack(self, target):
        target.hp -= self.damage
        print(f"{self.name} attacks {target.name} for {self.damage} damage!")

    def is_alive(self):
        return self.hp > 0

class Player(Character):
    ROLE_STATS = {
        "Novice": (100, 10),
        "Swordsman": (120, 15),
        "Archer": (100, 18),
        "Magician": (80, 25)
    }

    def __init__(self, name, role="Novice"):
        super().__init__(name, *self.ROLE_STATS[role])
        self.role = role

    def special_attack(self, target):
        special_damage = {"Swordsman": 30, "Archer": 35, "Magician": 50}.get(self.role, 0)
        target.hp -= special_damage
        print(f"{self.name} uses special attack for {special_damage} damage!")

    def heal(self):
        if self.role == "Magician":
            self.hp += 20
            print(f"{self.name} heals for 20 HP!")

class Monster(Character):
    def __init__(self):
        super().__init__("Monster", 150, 12)

class Game:
    def __init__(self):
        self.player_wins = {}
        self.start_game()

    def choose_role(self, is_first=True):
        roles = ["Swordsman", "Archer", "Magician"]
        if is_first:
            return Player(input("Enter your name: "))
        while True:
            print("Choose your new role: 1. Swordsman 2. Archer 3. Magician")
            choice = input("Enter choice: ")
            if choice in ["1", "2", "3"]:
                return Player(input("Enter your name: "), roles[int(choice) - 1])
            print("Invalid choice. Try again.")

    def battle(self, player, enemy):
        while player.is_alive() and enemy.is_alive():
            attacker, defender = random.sample([player, enemy], 2)
            print(f"{attacker.name}'s turn!")
            if isinstance(attacker, Monster):
                attacker.attack(defender)
            else:
                while True:
                    print("Choose attack: 1. Basic Attack 2. Special Attack" + (" 3. Heal" if player.role == "Magician" else ""))
                    move = input("Enter choice: ")
                    if move == "1":
                        attacker.attack(defender)
                        break
                    elif move == "2":
                        attacker.special_attack(defender)
                        break
                    elif move == "3" and attacker.role == "Magician":
                        attacker.heal()
                        break
                    print("Invalid choice. Try again.")
            print(f"{defender.name} HP: {defender.hp}")

        winner = player if player.is_alive() else enemy
        print(f"{winner.name} wins!")
        self.player_wins[winner.name] = self.player_wins.get(winner.name, 0) + 1
        print(f"{winner.name} has won {self.player_wins[winner.name]} times!")
        return player if player.is_alive() else None

    def single_player(self):
        player = self.choose_role()
        while True:
            print("A Monster appears!")
            if self.battle(player, Monster()):
                if self.player_wins[player.name] == 2:
                    print("You can choose a new role!")
                    player = self.choose_role(False)
                    self.player_wins[player.name] = 0
            else:
                print("You lost. Game over.")
                break

    def pvp(self):
        print("Player 1:")
        player1 = self.choose_role(False)
        print("Player 2:")
        player2 = self.choose_role(False)
        self.battle(player1, player2)

    def start_game(self):
        while True:
            print("Choose Mode: 1. Single Player 2. PvP 3. Exit")
            mode = input("Enter choice: ")
            if mode == "1":
                self.single_player()
            elif mode == "2":
                self.pvp()
            elif mode == "3":
                print("Exiting game...")
                break
            else:
                print("Invalid choice. Try again.")

if __name__ == "__main__":
    Game()
# Out:
# Choose Mode: 1. Single Player 2. PvP 3. Exit
# Enter choice: 1
# Enter your name: Ken
# A Monster appears!
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 10 damage!
# Monster HP: 140
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 2
# Ken uses special attack for 0 damage!
# Monster HP: 140
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 2
# Ken uses special attack for 0 damage!
# Monster HP: 140
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 10 damage!
# Monster HP: 130
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 10 damage!
# Monster HP: 120
# Monster's turn!
# Monster attacks Ken for 12 damage!
# Ken HP: 88
# Monster's turn!
# Monster attacks Ken for 12 damage!
# Ken HP: 76
# Monster's turn!
# Monster attacks Ken for 12 damage!
# Ken HP: 64
# Monster's turn!
# Monster attacks Ken for 12 damage!
# Ken HP: 52
# Monster's turn!
# Monster attacks Ken for 12 damage!
# Ken HP: 40
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 10 damage!
# Monster HP: 110
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 2
# Ken uses special attack for 0 damage!
# Monster HP: 110
# Monster's turn!
# Monster attacks Ken for 12 damage!
# Ken HP: 28
# Monster's turn!
# Monster attacks Ken for 12 damage!
# Ken HP: 16
# Monster's turn!
# Monster attacks Ken for 12 damage!
# Ken HP: 4
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 10 damage!
# Monster HP: 100
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 2
# Ken uses special attack for 0 damage!
# Monster HP: 100
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack
# Enter choice: 1
# Ken attacks Monster for 10 damage!
# Monster HP: 90
# Monster's turn!
# Monster attacks Ken for 12 damage!
# Ken HP: -8
# Monster wins!
# Monster has won 1 times!
# You lost. Game over.
# Choose Mode: 1. Single Player 2. PvP 3. Exit
# Enter choice: 2
# Player 1:
# Choose your new role: 1. Swordsman 2. Archer 3. Magician
# Enter choice: 3
# Enter your name: Ken
# Player 2:
# Choose your new role: 1. Swordsman 2. Archer 3. Magician
# Enter choice: 1
# Enter your name: Kenneth
# Kenneth's turn!
# Choose attack: 1. Basic Attack 2. Special Attack 3. Heal
# Enter choice: 1
# Kenneth attacks Ken for 15 damage!
# Ken HP: 65
# Kenneth's turn!
# Choose attack: 1. Basic Attack 2. Special Attack 3. Heal
# Enter choice: 2
# Kenneth uses special attack for 30 damage!
# Ken HP: 35
# Kenneth's turn!
# Choose attack: 1. Basic Attack 2. Special Attack 3. Heal
# Enter choice: 1
# Kenneth attacks Ken for 15 damage!
# Ken HP: 20
# Kenneth's turn!
# Choose attack: 1. Basic Attack 2. Special Attack 3. Heal
# Enter choice: 1
# Kenneth attacks Ken for 15 damage!
# Ken HP: 5
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack 3. Heal
# Enter choice: 2
# Ken uses special attack for 50 damage!
# Kenneth HP: 70
# Ken's turn!
# Choose attack: 1. Basic Attack 2. Special Attack 3. Heal
# Enter choice: 2
# Ken uses special attack for 50 damage!
# Kenneth HP: 20
# Kenneth's turn!
# Choose attack: 1. Basic Attack 2. Special Attack 3. Heal
# Enter choice: 2
# Kenneth uses special attack for 30 damage!
# Ken HP: -25
# Kenneth wins!
# Kenneth has won 1 times!
# Choose Mode: 1. Single Player 2. PvP 3. Exit
# Enter choice: 3
# Exiting game...
